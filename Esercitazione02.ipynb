# %%
def sommaduenum(x,y):
  ris = x+y
  return ris

# %%
sommaduenum(-150,100)
# Out:
# -50

# %%
def paridispari(x):
  if x%2==0:
    return "Il numero è pari"
  else:
    return "Il numero è dispari"

# %%
n = int(input("Inserisci un numero intero "))
print(paridispari(n))

# %%
# %%writefile formulario.py

def areaTriangolo(b,h):
  return (b*h)/2
# Out:
# Overwriting formulario.py

# %%
base = float(input("Inserisci il valore della base "))
altezza = float(input("Inserisci il valore dell'altezza "))
print(round(areaTriangolo(base,altezza),2))

# %%
from formulario import areaTriangolo as at

# %%
at(4,7)
# Out:
# 14.0

# %%
# %%writefile formulario.py

def perimTriangolo(a,b,c):
  return a+b+c

def areaTriangolo(b,h):
  return (b*h)/2
# Out:
# Overwriting formulario.py

# %%
from formulario import perimTriangolo as pt

# %%
pt(2,6,8)
# Out:
# 16

# %%
cd /content/drive/MyDrive/Colab Notebooks/Esercitazioni
# Out:
# /content/drive/MyDrive/Colab Notebooks/Esercitazioni

# %%
ls
# Out:
# 01_intro.ipynb  Esercitazione02.ipynb  Markdown_Colab.ipynb
# albero.jpg      formulario.py          README.md

# %%
# %matplotlib inline   #si mette solo qui on line su notebook, su python pc no!!

# %%
import matplotlib.pyplot as plt

import numpy as np 
from numpy.random import rand

# %%
y = rand(100)
y
# Out:
# array([0.69411796, 0.32054072, 0.4210083 , 0.23810977, 0.10632097,
#        0.13625049, 0.83313913, 0.957489  , 0.95535644, 0.39082051,
#        0.78225531, 0.11164646, 0.3140648 , 0.53845583, 0.12705091,
#        0.95205797, 0.34863575, 0.37949573, 0.88341637, 0.43696743,
#        0.23618585, 0.15210787, 0.42254564, 0.65263732, 0.04748616,
#        0.47471582, 0.07300508, 0.49037961, 0.32835544, 0.01847274,
#        0.65609658, 0.46189801, 0.7854774 , 0.90751699, 0.35985873,
#        0.36378666, 0.10451117, 0.28326811, 0.25865   , 0.47994083,
#        0.32166435, 0.63674117, 0.85210465, 0.58679112, 0.59180727,
#        0.73804887, 0.29777065, 0.01520235, 0.22442288, 0.90675128,
#        0.19306991, 0.97725112, 0.60122805, 0.50440313, 0.64734888,
#        0.08482284, 0.24330667, 0.9714611 , 0.32876966, 0.95193286,
#        0.25684039, 0.61594521, 0.45636073, 0.36469243, 0.40974855,
#        0.95586306, 0.59803263, 0.54043598, 0.84788656, 0.73697596,
# ...

# %%
y.size
# Out:
# 100

# %%
y.ndim
# Out:
# 1

# %%
x = rand(1000)
y = rand(1000)

plt.scatter(x,y);
#plt.show()  serve se non siamo sul notebook ma su python pc

# %%
plt.scatter(x,y,color="purple");
#plt.show()

# %%
plt.plot([10,20,30,40], '--r')  #prende 10,20,30,40 sulle y, per le x vede la len[]=4 e divide l'intervallo in 4 punti a partire da (0,0) 
plt.ylabel('label y');          # 'r'=red, '--'=tratteggiato 
#plt.show()

# %%
plt.plot([1,2,3,4],[1,2,3,4], 'g');    #'g'=green
#plt.show()

# %%
x = np.linspace(0,10,100)
y = np.exp(-x)
plt.plot(x,y);
#plt.show()

# %%
x = np.linspace(0,10,100)

plt.figure(figsize=(18,10))  #se non ci metto nulla fa lui plt.figure()
plt.title('Sin & Cos')
plt.plot(x, np.sin(x), '-', label='sin')
plt.plot(x, np.cos(x), '--', label='cos')
plt.legend(loc='lower right');
